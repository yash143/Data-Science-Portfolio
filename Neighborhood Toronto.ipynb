# %% [markdown]
# <h1>Torontos Neighborhood</h1>

# %% [markdown]
# This assignement clusters the neighborhood in Toronto.

# %% [markdown]
# <h3>Scrape the Wikipedia page</h3>
#
# This part scrapes the wikipedia page given and extract a data frame from that.

# %%
# import libraries and packages
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import pandas as pd

# %%
# get data from webpage by using BuitifulSoup
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# %%
## extract data table
# separate table in headlines and columns
tableWiki = soup.findAll('table')[0]
headline = tableWiki.findAll('th')
rows = tableWiki.findAll('tr')

# get all table entries
postcode = []
borough = []
neighborhood = []
for i in range(1,len(rows)):
    temp_rows = rows[i].findAll('td')
    current_postcode = temp_rows[0].text
    current_borough = temp_rows[1].text
    current_neighborhood = temp_rows[2].text[:-1]
    # remove all rows where borough is 'Not assigned'
    if current_borough != 'Not assigned':
        # check whether postal code already exist
        exist = False
        for j, temp in enumerate(postcode):
            if temp == current_postcode:
                neighborhood[j] = neighborhood[j]+', '+current_neighborhood
                exist = True
        if exist == False:
            # check neighborhood for 'Not Assigned'
            if current_neighborhood == 'Not assigned':
                current_neighborhood = current_borough
            postcode.append(current_postcode)
            borough.append(current_borough)
            neighborhood.append(current_neighborhood)

# create data frame in pandas
df = pd.DataFrame({headline[0].text:postcode,
                  headline[1].text:borough,
                  headline[2].text[:-1]:neighborhood})
df.head()
# Out:
#   Postcode           Borough                     Neighbourhood
# 0      M3A        North York                         Parkwoods
# 1      M4A        North York                  Victoria Village
# 2      M5A  Downtown Toronto         Harbourfront, Regent Park
# 3      M6A        North York  Lawrence Heights, Lawrence Manor
# 4      M7A      Queen's Park                      Queen's Park

# %%
# show number of rows for the data frame
df.shape
# Out:
# (103, 3)

# %% [markdown]
# <h3>Get the coordinates of each neighborhood</h3>
#
# This part uses the csv file to get the coordinates of each neighborhood.

# %%
# create dataframe from csv file
df_coordinates = pd.read_csv('Geospatial_Coordinates.csv')
df_coordinates.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
## append to the data frame the Latitude and Longitude
# sort values of each data frame
df.sort_values(by=['Postcode'], inplace = True)
df_coordinates.sort_values(by=['Postal Code'], inplace = True)
# create new data Frame
df_temp1 = pd.DataFrame(df_coordinates['Latitude'])
df_temp2 = pd.DataFrame(df_coordinates['Longitude'])
df['Latitude'] = df_temp1
df['Longitude'] = df_temp2
df.head()
# Out:
#    Postcode      Borough                           Neighbourhood   Latitude  \
# 6       M1B  Scarborough                          Rouge, Malvern  43.727929
# 12      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.794200
# 18      M1E  Scarborough       Guildwood, Morningside, West Hill  43.778517
# 22      M1G  Scarborough                                  Woburn  43.770120
# 26      M1H  Scarborough                               Cedarbrae  43.745906
#
#     Longitude
# 6  -79.262029
# 12 -79.262029
# 18 -79.346556
# 22 -79.408493
# 26 -79.352188

# %% [markdown]
# <h3>Explore and Clustering the neighborhoods in Toronto</h3>
#
# <h5>Create a map of Toronto</h5>

# %%
# import packages
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import json
from pandas.io.json import json_normalize
import numpy as np

# %% [markdown]
# This part creates a map of the different in neighborhoods in Toronto. The map is saved in the wd, because the presentation does not work on this browser. You can easily use "map_toronto" to plot the map.

# %%
latitude = 43.70011
longitude = -79.4163
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto.save(outfile = 'Map_Toronto.html')

# %%
# connect to Foursuqare api
CLIENT_ID = 'R32VDER01KIPAABYQGIPAL1LDDSPVLA1WOVUL5WCTGMPW5GA' 
CLIENT_SECRET = 'TS3S0DHH5JIOZDEBJJAAMURIBGIHPF1EL0CVCX1IXD4VTAKA' 
VERSION = '20180605'

# %% [markdown]
# In this section we get the Top 100 venues in the first neighborhood. In the second cell the data are stored in a data frame.

# %%
neighborhood_id = 2
neighborhood_latitude = df.loc[neighborhood_id, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = df.loc[neighborhood_id, 'Longitude'] # neighborhood longitude value
neighborhood_name = df.loc[neighborhood_id, 'Neighbourhood'] # neighborhood name

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=300):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=df['Neighbourhood'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
print(toronto_venues.shape)
toronto_venues.head()
toronto_venues.groupby('Neighborhood').count()
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# (1214, 7)
# There are 219 uniques categories.

# %% [markdown]
# <h4>Analyzing und clustering each neighborhood</h4>

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

num_top_venues = 6

indicators = ['st', 'nd', 'rd']


# function for sorting venues in descending order
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

# %%
# set number of clusters
kclusters = 4

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = df

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighbourhood')

toronto_merged.head() # check the last columns!
# Out:
#    Postcode      Borough                           Neighbourhood   Latitude  \
# 6       M1B  Scarborough                          Rouge, Malvern  43.727929
# 12      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.794200
# 18      M1E  Scarborough       Guildwood, Morningside, West Hill  43.778517
# 22      M1G  Scarborough                                  Woburn  43.770120
# 26      M1H  Scarborough                               Cedarbrae  43.745906
#
#     Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 6  -79.262029             0.0     Convenience Store            Playground
# 12 -79.262029             0.0        Breakfast Spot        Sandwich Place
# 18 -79.346556             0.0        Clothing Store  Fast Food Restaurant
# 22 -79.408493             2.0           Coffee Shop         Women's Store
# 26 -79.352188             0.0          Tennis Court         Women's Store
#
#    3rd Most Common Venue       4th Most Common Venue 5th Most Common Venue  \
# 6          Women's Store                    Dive Bar                 Field
# 12               Dog Run  Financial or Legal Service                 Field
# 18         Women's Store                 Coffee Shop            Shoe Store
# 22              Dive Bar  Financial or Legal Service                 Field
# 26           Fish Market  Financial or Legal Service                 Field
#
#    6th Most Common Venue
# 6   Fast Food Restaurant
# 12  Fast Food Restaurant
# 18   Japanese Restaurant
# 22  Fast Food Restaurant
# 26  Fast Food Restaurant

# %%
# create a map for clustering
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster Labels']):
    if np.isnan(cluster) == False:
        label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
        folium.CircleMarker(
            [lat, lon],
            radius=5,
            popup=label,
            color=rainbow[int(cluster)-1],
            fill=True,
            fill_color=rainbow[int(cluster)-1],
            fill_opacity=0.7).add_to(map_clusters)
       
map_clusters.save(outfile = 'Map_Toronto_Cluster.html')

# %% [markdown]
# <h4>Examine Cluster</h4>

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels     1st Most Common Venue  \
# 6        Scarborough             0.0         Convenience Store
# 12       Scarborough             0.0            Breakfast Spot
# 18       Scarborough             0.0            Clothing Store
# 26       Scarborough             0.0              Tennis Court
# 32       Scarborough             0.0            Baseball Field
# 38       Scarborough             0.0       Sporting Goods Shop
# 44       Scarborough             0.0        Photography Studio
# 51       Scarborough             0.0               Pizza Place
# 58       Scarborough             0.0                Steakhouse
# 65       Scarborough             0.0                      Park
# 71       Scarborough             0.0    Furniture / Home Store
# 78       Scarborough             0.0                      Café
# 85       Scarborough             0.0               Coffee Shop
# 90       Scarborough             0.0                      Pool
# 95       Scarborough             0.0                  Pharmacy
# 27        North York             0.0          Asian Restaurant
# 33        North York             0.0              Liquor Store
# 39        North York             0.0         Indian Restaurant
# 45        North York             0.0               Flower Shop
# 52        North York             0.0                   Gay Bar
# 59        North York             0.0               Coffee Shop
# 66        North York             0.0                      Café
# 72        North York             0.0               Pizza Place
# 13        North York             0.0      Fast Food Restaurant
# 28        North York             0.0               Coffee Shop
# 34        North York             0.0              Intersection
# 46        North York             0.0                  Boutique
# 53        North York             0.0                       Spa
# 60        North York             0.0               Coffee Shop
# 8          East York             0.0                     Motel
# ..               ...             ...                       ...
# 9   Downtown Toronto             0.0               Pizza Place
# 15  Downtown Toronto             0.0        Chinese Restaurant
# 36  Downtown Toronto             0.0              Dance Studio
# 42  Downtown Toronto             0.0             Burrito Place
# 55        North York             0.0               Coffee Shop
# 62   Central Toronto             0.0        Italian Restaurant
# 68   Central Toronto             0.0        Airport Food Court
# 80  Downtown Toronto             0.0            Discount Store
# 84  Downtown Toronto             0.0          Sushi Restaurant
# 87  Downtown Toronto             0.0                      Park
# 92  Downtown Toronto             0.0               Wings Joint
# 3         North York             0.0         Korean Restaurant
# 10        North York             0.0         Indian Restaurant
# 31      West Toronto             0.0              Home Service
# 43      West Toronto             0.0               Coffee Shop
# 49        North York             0.0               Coffee Shop
# 56              York             0.0              Concert Hall
# 63              York             0.0   Health & Beauty Service
# 69      West Toronto             0.0              Cocktail Bar
# 75      West Toronto             0.0             Grocery Store
# 4       Queen's Park             0.0           Thai Restaurant
# 76       Mississauga             0.0                  Pharmacy
# 5          Etobicoke             0.0                Playground
# 17         Etobicoke             0.0  Mediterranean Restaurant
# 50        North York             0.0                  Building
# 57        North York             0.0               Coffee Shop
# 64              York             0.0    Furniture / Home Store
# 70         Etobicoke             0.0               Coffee Shop
# 77         Etobicoke             0.0                       Bar
# 89         Etobicoke             0.0                  Pharmacy
#
#     2nd Most Common Venue       3rd Most Common Venue  \
# 6              Playground               Women's Store
# 12         Sandwich Place                     Dog Run
# 18   Fast Food Restaurant               Women's Store
# 26          Women's Store                 Fish Market
# 32          Women's Store                 Flower Shop
# 38       Sushi Restaurant              Breakfast Spot
# 44               Dive Bar  Financial or Legal Service
# 51                   Café                 Coffee Shop
# 58            Coffee Shop                         Bar
# 65         Sandwich Place               Metro Station
# 71          Women's Store                 Coffee Shop
# 78         Sandwich Place                  Restaurant
# 85     Italian Restaurant             Bubble Tea Shop
# 90          Women's Store              Discount Store
# 95             Beer Store                 Pizza Place
# 27            Coffee Shop                  Restaurant
# 33          Women's Store                     Dog Run
# 39         Sandwich Place                 Yoga Studio
# 45                    Gym               Grocery Store
# 52           Burger Joint                 Coffee Shop
# 59                   Café         Sporting Goods Shop
# 66            Coffee Shop              Sandwich Place
# 72       Sushi Restaurant            Asian Restaurant
# 13          Shopping Mall                        Bank
# 28   Fast Food Restaurant                  Restaurant
# 34  Portuguese Restaurant  Financial or Legal Service
# 46          Women's Store                     Dog Run
# 53   Gym / Fitness Center              History Museum
# 60             Restaurant               Deli / Bodega
# 8     American Restaurant               Women's Store
# ..                    ...                         ...
# 9                    Café               Women's Store
# 15   Fast Food Restaurant                 Coffee Shop
# 36             Beer Store                    Bus Stop
# 42          Movie Theater            Sushi Restaurant
# 55              Gastropub          Italian Restaurant
# 62            Coffee Shop                Liquor Store
# 68           Airport Gate              Airport Lounge
# 80            Coffee Shop                  Restaurant
# 84            Pizza Place                   Gastropub
# 87     Light Rail Station        Fast Food Restaurant
# 92        Supplement Shop           Convenience Store
# 3           Women's Store                     Dog Run
# 10          Women's Store                    Dive Bar
# 31          Women's Store                    Dive Bar
# 43                   Café          Italian Restaurant
# 49           Liquor Store                        Park
# 56         Breakfast Spot                Liquor Store
# 63                Dog Run           Fish & Chips Shop
# 69            Coffee Shop                         Pub
# 75    American Restaurant                 Candy Store
# 4      Athletics & Sports                        Bank
# 76                   Bank                         Bar
# 5           Women's Store              Discount Store
# 17                   Pool                 Golf Course
# 50          Women's Store                     Dog Run
# 57         Sandwich Place          Italian Restaurant
# 64          Women's Store                     Dog Run
# 70                   Café               Deli / Bodega
# 77       Asian Restaurant     New American Restaurant
# 89            Pizza Place                         Gym
#
#          4th Most Common Venue       5th Most Common Venue  \
# 6                     Dive Bar                       Field
# 12  Financial or Legal Service                       Field
# 18                 Coffee Shop                  Shoe Store
# 26  Financial or Legal Service                       Field
# 32           Fish & Chips Shop  Financial or Legal Service
# 38                  Restaurant          Mexican Restaurant
# 44                       Field        Fast Food Restaurant
# 51          Italian Restaurant         Japanese Restaurant
# 58         American Restaurant            Asian Restaurant
# 65                 Cheese Shop                        Café
# 71              Clothing Store                 Event Space
# 78              Breakfast Spot                         Gym
# 85              Sandwich Place       Portuguese Restaurant
# 90                       Field        Fast Food Restaurant
# 95                 Coffee Shop                        Café
# 27         Japanese Restaurant          Italian Restaurant
# 33  Financial or Legal Service                       Field
# 39                    Bus Line                 Supermarket
# 45              Breakfast Spot                     Dog Run
# 52         Japanese Restaurant                        Park
# 59                 Pizza Place                       Hotel
# 66                      Bakery         Japanese Restaurant
# 72         Japanese Restaurant               Women's Store
# 13               Women's Store                 Fish Market
# 28            Sushi Restaurant   Middle Eastern Restaurant
# 34                Hockey Arena                 Pizza Place
# 46           Fish & Chips Shop  Financial or Legal Service
# 53                 Coffee Shop                  Food Truck
# 60                        Café         American Restaurant
# 8   Financial or Legal Service                       Field
# ..                         ...                         ...
# 9                     Dive Bar                       Field
# 15         American Restaurant           Electronics Store
# 36               Women's Store         Dumpling Restaurant
# 42                Intersection        Fast Food Restaurant
# 55                  Restaurant                       Hotel
# 62                         Pub                   Juice Bar
# 68            Airport Terminal                 Coffee Shop
# 80              Sandwich Place                    Dive Bar
# 84           French Restaurant                        Café
# 87              Farmers Market               Auto Workshop
# 92              Discount Store        Fast Food Restaurant
# 3   Financial or Legal Service                       Field
# 10  Financial or Legal Service                       Field
# 31  Financial or Legal Service                       Field
# 43   Latin American Restaurant             Thai Restaurant
# 49                 Supermarket          Athletics & Sports
# 56                  Steakhouse                    Beer Bar
# 63  Financial or Legal Service                       Field
# 69                    Beer Bar              Breakfast Spot
# 75        Gym / Fitness Center                        Café
# 4         Caribbean Restaurant                      Lounge
# 76   Middle Eastern Restaurant                 Supermarket
# 5                        Field        Fast Food Restaurant
# 17          Athletics & Sports                     Dog Run
# 50  Financial or Legal Service                       Field
# 57                        Café                 Pizza Place
# 64  Financial or Legal Service                       Field
# 70                  Restaurant                 Salad Place
# 77                      Bakery       Vietnamese Restaurant
# 89                 Coffee Shop                         Pub
#
#          6th Most Common Venue
# 6         Fast Food Restaurant
# 12        Fast Food Restaurant
# 18         Japanese Restaurant
# 26        Fast Food Restaurant
# 32                       Field
# 38           Electronics Store
# 44              Farmers Market
# 51                    Dive Bar
# 58          Seafood Restaurant
# 65           Indian Restaurant
# 71                    Boutique
# 78               Grocery Store
# 85                        Park
# 90              Farmers Market
# 95              Shopping Plaza
# 27                   Bike Shop
# 33        Fast Food Restaurant
# 39                 Coffee Shop
# 45  Financial or Legal Service
# 52          Mexican Restaurant
# 59              Sandwich Place
# 66          Chinese Restaurant
# 72                     Dog Run
# 13  Financial or Legal Service
# 28                 Supermarket
# 34           French Restaurant
# 46                       Field
# 53                      Bakery
# 60                   Gastropub
# 8         Fast Food Restaurant
# ..                         ...
# 9         Fast Food Restaurant
# 15              Sandwich Place
# 36           Fish & Chips Shop
# 42                  Board Shop
# 55         Japanese Restaurant
# 62              Sandwich Place
# 68               Women's Store
# 80                       Field
# 84                         Bar
# 87                     Brewery
# 92                 Social Club
# 3         Fast Food Restaurant
# 10        Fast Food Restaurant
# 31        Fast Food Restaurant
# 43                 Fish Market
# 49                         Spa
# 56          Italian Restaurant
# 63        Fast Food Restaurant
# 69          Italian Restaurant
# 75         Japanese Restaurant
# 4             Hakka Restaurant
# 76                 Music Venue
# 5               Farmers Market
# 17               Women's Store
# 50        Fast Food Restaurant
# 57               Smoothie Shop
# 64        Fast Food Restaurant
# 70          Seafood Restaurant
# 77                 Coffee Shop
# 89                       Diner
#
# [75 rows x 8 columns]

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster Labels 1st Most Common Venue  \
# 40         North York             1.0                  Park
# 23          East York             1.0     Convenience Store
# 48   Downtown Toronto             1.0                  Park
# 74    Central Toronto             1.0         Women's Store
# 25   Downtown Toronto             1.0                  Park
# 37       West Toronto             1.0                  Park
# 100      East Toronto             1.0                  Park
# 98          Etobicoke             1.0                  Park
#
#           2nd Most Common Venue 3rd Most Common Venue  \
# 40   Construction & Landscaping         Women's Store
# 23                         Park                  Bank
# 48                Shopping Mall         Women's Store
# 74                         Park                Market
# 25         Fast Food Restaurant         Women's Store
# 37         Other Great Outdoors                 Trail
# 100                    Bus Line         Women's Store
# 98                Women's Store              Dive Bar
#
#           4th Most Common Venue       5th Most Common Venue  \
# 40                      Dog Run  Financial or Legal Service
# 23                      Dog Run  Financial or Legal Service
# 48                     Dive Bar                       Field
# 74         Fast Food Restaurant                    Dive Bar
# 25                     Dive Bar  Financial or Legal Service
# 37                Women's Store                    Dive Bar
# 100                    Dive Bar                       Field
# 98   Financial or Legal Service                       Field
#
#     6th Most Common Venue
# 40                  Field
# 23                  Field
# 48   Fast Food Restaurant
# 74                  Field
# 25                  Field
# 37                  Field
# 100  Fast Food Restaurant
# 98   Fast Food Restaurant

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 22       Scarborough             2.0           Coffee Shop
# 24  Downtown Toronto             2.0           Coffee Shop
#
#    2nd Most Common Venue 3rd Most Common Venue       4th Most Common Venue  \
# 22         Women's Store              Dive Bar  Financial or Legal Service
# 24         Women's Store              Dive Bar  Financial or Legal Service
#
#    5th Most Common Venue 6th Most Common Venue
# 22                 Field  Fast Food Restaurant
# 24                 Field  Fast Food Restaurant

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels       1st Most Common Venue  \
# 97  Downtown Toronto             3.0  Construction & Landscaping
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 97         Women's Store               Dog Run     Fish & Chips Shop
#
#          5th Most Common Venue 6th Most Common Venue
# 97  Financial or Legal Service                 Field
